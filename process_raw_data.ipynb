# %%
import pandas as pd
import numpy as np

# %%
daily_shopee_sales = pd.read_csv('shopee_date_merged.csv')

# %%
daily_shopee_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11130 entries, 0 to 11129
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Channel                     11130 non-null  object
#  1   Date                        11130 non-null  object
#  2   Product ID                  10787 non-null  float64
#  3   Product name                10787 non-null  object
#  4   Product category            10787 non-null  object
#  5   Brand                       10787 non-null  object
#  6   All traffic                 10787 non-null  float64
#  7   All impressions             10787 non-null  float64
#  8   Orders                      10787 non-null  float64
#  9   Payment                     10787 non-null  float64
#  10  Revenue                     10787 non-null  float64
#  11  Product name_Map            10787 non-null  object
#  12  Sponsored product name      1718 non-null   object
# ...

# %%
daily_shopee_sales.head()
# Out:
#   Channel        Date    Product ID  \
# 0  Shopee  2024-05-01  3.988320e+09
# 1  Shopee  2024-05-01  5.088478e+09
# 2  Shopee  2024-05-01  6.288245e+09
# 3  Shopee  2024-05-01  7.188245e+09
# 4  Shopee  2024-05-01  8.452338e+09
#
#                                         Product name  \
# 0  Combo giấy lọc Melitta 1x6 - Nhập khấu chính h...
# 1         Không thể lấy thông tin sản phẩm do bị xóa
# 2  Cà phê hạt Carraro Globo Rosso - Nhập khẩu từ ...
# 3  Cà phê hạt Carraro Globo Oro - Nhập khẩu từ Ý ...
# 4  Combo 3 Hộp Giấy Lọc Cà Phê Melitta 100-Nhập k...
#
#             Product category    Brand  All traffic  All impressions  Orders  \
# 0  6. Other Melitta products  Melitta          2.0              3.0     1.0
# 1          0. Other products   Others          1.0              1.0     0.0
# 2            4. Carraro bean  Carraro          4.0              8.0     0.0
# 3            4. Carraro bean  Carraro          1.0              3.0     0.0
# ...
